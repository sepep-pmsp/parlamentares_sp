# %%
import pandas as pd
from utils.load_csv import load_csv

# %%
resultados_2022 = load_csv('resultados_2022.csv')

# %%
resultados_2022.shape
# Out:
# (18761482, 26)

# %%
pd.set_option('display.max_columns', None)

resultados_2022.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  01/11/2022   16:05:25         2022                2  ELEIÇÃO ORDINÁRIA
# 1  01/11/2022   16:05:25         2022                2  ELEIÇÃO ORDINÁRIA
# 2  01/11/2022   16:05:25         2022                2  ELEIÇÃO ORDINÁRIA
# 3  01/11/2022   16:05:25         2022                2  ELEIÇÃO ORDINÁRIA
# 4  01/11/2022   16:05:25         2022                2  ELEIÇÃO ORDINÁRIA
#
#    NR_TURNO  CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO  \
# 0         1         546  ELEIÇÕES GERAIS ESTADUAIS 2022  02/10/2022
# 1         1         546  ELEIÇÕES GERAIS ESTADUAIS 2022  02/10/2022
# 2         1         546  ELEIÇÕES GERAIS ESTADUAIS 2022  02/10/2022
# 3         1         546  ELEIÇÕES GERAIS ESTADUAIS 2022  02/10/2022
# 4         1         546  ELEIÇÕES GERAIS ESTADUAIS 2022  02/10/2022
#
#   TP_ABRANGENCIA SG_UF SG_UE      NM_UE  CD_MUNICIPIO     NM_MUNICIPIO  \
# 0              E    SP    SP  SÃO PAULO         71072        SÃO PAULO
# 1              E    SP    SP  SÃO PAULO         62197            BAURU
# 2              E    SP    SP  SÃO PAULO         71072        SÃO PAULO
# 3              E    SP    SP  SÃO PAULO         64777        GUARULHOS
# 4              E    SP    SP  SÃO PAULO         67130  MOGI DAS CRUZES
#
#    NR_ZONA  NR_SECAO  CD_CARGO          DS_CARGO  NR_VOTAVEL  \
# 0      320        42         6  DEPUTADO FEDERAL        2200
# 1       23       261         6  DEPUTADO FEDERAL        2200
# 2      253       614         6  DEPUTADO FEDERAL        2200
# 3      393       315         6  DEPUTADO FEDERAL        2200
# 4      287        72         6  DEPUTADO FEDERAL        2200
#
#           NM_VOTAVEL  QT_VOTOS  NR_LOCAL_VOTACAO  SQ_CANDIDATO  \
# 0  JOSÉ AUGUSTO ROSA         2              1031  250001611357
# 1  JOSÉ AUGUSTO ROSA        16              1970  250001611357
# 2  JOSÉ AUGUSTO ROSA         1              2135  250001611357
# 3  JOSÉ AUGUSTO ROSA         3              1252  250001611357
# 4  JOSÉ AUGUSTO ROSA         1              1120  250001611357
#
#                                     NM_LOCAL_VOTACAO  \
# 0  EE. DOUTOR CARLOS AUGUSTO DE FREITAS VILLALVA ...
# 1                        EMEF IVAN ENGLER DE ALMEIDA
# 2     FACULDADE E COLÉGIO CARLOS DRUMMOND DE ANDRADE
# 3                          EM. PADRE MANUEL DE PAIVA
# 4                       EE. LEONOR DE OLIVEIRA MELLO
#
#                        DS_LOCAL_VOTACAO_ENDERECO
# 0  AV. ENGENHEIRO ARMANDO DE ARRUDA PEREIRA, 506
# 1                    AVENIDA MARIA RANIERI, 4-30
# 2        RUA PROF. PEDREIRA DE FREITAS, 401, 415
# 3                       AV. FRANCISCO CONDE, 600
# 4               RUA JOAQUINA MARIA DE JESUS, 641

# %%
resultados_2022['DS_CARGO'].unique()
# Out:
# array(['DEPUTADO FEDERAL', 'DEPUTADO ESTADUAL', 'GOVERNADOR', 'SENADOR'],
#       dtype=object)
