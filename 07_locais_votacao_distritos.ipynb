# %% [markdown]
# ## Locais votação distritos

# %% [markdown]
# Nesse notebook são definidos os distritos dos locais de votação

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
from utils.load_csv import load_csv
from utils.load_shp import load_shp
from utils.save_csv import save_csv

# %%
locais_votacao_geoloc = load_csv('locais_votacao_geoloc.csv',
                                 sep=';',
                                 engine='python')

# %%
distritos = load_shp('distritos.shp')

# %%
locais_votacao_geoloc.loc[40, 'end_resultado'] = "R. Mont'Alverne, 91 - Vila São José, São Paulo - SP, 04265-060"
locais_votacao_geoloc.loc[40, 'lat'] = -23.584614
locais_votacao_geoloc.loc[40, 'lon'] = -46.616127
locais_votacao_geoloc.loc[40, 'score'] = 1.0

locais_votacao_geoloc.loc[174, 'end_resultado'] = "R. Filomena Belmont, 75 - Marsilac, São Paulo - SP, 04891-370"
locais_votacao_geoloc.loc[174, 'lat'] = -23.908274
locais_votacao_geoloc.loc[174, 'lon'] = -46.707745
locais_votacao_geoloc.loc[174, 'score'] = 1.0

locais_votacao_geoloc.loc[258, 'end_resultado'] = "R. Nossa Sra. da Conceição, 226 - Jaraguá, São Paulo - SP, 05181-280"
locais_votacao_geoloc.loc[258, 'lat'] = -23.454049
locais_votacao_geoloc.loc[258, 'lon'] = -46.742028
locais_votacao_geoloc.loc[258, 'score'] = 1.0

locais_votacao_geoloc.loc[276, 'end_resultado'] = "Av. Nossa Sra. de Guadalupe, 212 - Jardim Helena, São Paulo - SP, 08420-130"
locais_votacao_geoloc.loc[276, 'lat'] = -23.539248
locais_votacao_geoloc.loc[276, 'lon'] = -46.428363
locais_votacao_geoloc.loc[276, 'score'] = 1.0

locais_votacao_geoloc.loc[360, 'end_resultado'] = "R. Godói Bueno, 19 - Jardim Santo Andre, São Paulo - SP, 08390-400"
locais_votacao_geoloc.loc[360, 'lat'] = -23.633848
locais_votacao_geoloc.loc[360, 'lon'] = -46.444696
locais_votacao_geoloc.loc[360, 'score'] = 1.0

locais_votacao_geoloc.loc[437, 'end_resultado'] = "R. Miguel Ferreira de Melo, 50 - Jardim Santo Andre, São Paulo - SP, 08390-000"
locais_votacao_geoloc.loc[437, 'lat'] = -23.630537
locais_votacao_geoloc.loc[437, 'lon'] = -46.443713
locais_votacao_geoloc.loc[437, 'score'] = 1.0

locais_votacao_geoloc.loc[495, 'end_resultado'] = "R. Vicente Jorge, 100 - Vila Bancaria Munhoz, São Paulo - SP, 02759-100"
locais_votacao_geoloc.loc[495, 'lat'] = -23.482174
locais_votacao_geoloc.loc[495, 'lon'] = -46.678388
locais_votacao_geoloc.loc[495, 'score'] = 1.0

locais_votacao_geoloc.loc[502, 'end_resultado'] = None
locais_votacao_geoloc.loc[502, 'lat'] = None
locais_votacao_geoloc.loc[502, 'lon'] = None
locais_votacao_geoloc.loc[502, 'score'] = None

locais_votacao_geoloc.loc[535, 'end_resultado'] = "Av. Vital Brasil, 1000 - Butantã, São Paulo - SP, 05503-001"
locais_votacao_geoloc.loc[535, 'lat'] = -23.568498
locais_votacao_geoloc.loc[535, 'lon'] = -46.713719
locais_votacao_geoloc.loc[535, 'score'] = 1.0

locais_votacao_geoloc.loc[627, 'end_resultado'] = "R. Dez de Maio, 271 - Vila Amélia, São Paulo - SP, 02615-100"
locais_votacao_geoloc.loc[627, 'lat'] = -23.470027
locais_votacao_geoloc.loc[627, 'lon'] = -46.655366
locais_votacao_geoloc.loc[627, 'score'] = 1.0

locais_votacao_geoloc.loc[651, 'end_resultado'] = "Rua Antônio de Camargo Ortiz, 2 - Parque Santa Amélia, São Paulo - SP, 08122-270"
locais_votacao_geoloc.loc[651, 'lat'] = -23.496527
locais_votacao_geoloc.loc[651, 'lon'] = -46.374548
locais_votacao_geoloc.loc[651, 'score'] = 1.0

locais_votacao_geoloc.loc[707, 'end_resultado'] = "Rua Três Rios, 362 - Bom Retiro, São Paulo - SP, 01123-000"
locais_votacao_geoloc.loc[707, 'lat'] = -23.528157
locais_votacao_geoloc.loc[707, 'lon'] = -46.637185
locais_votacao_geoloc.loc[707, 'score'] = 1.0

locais_votacao_geoloc.loc[744, 'end_resultado'] = "R. Joaquim dos Santos, 539 - Parque Alto do Rio Bonito, São Paulo - SP, 04823-080"
locais_votacao_geoloc.loc[744, 'lat'] = -23.725825
locais_votacao_geoloc.loc[744, 'lon'] = -46.698534
locais_votacao_geoloc.loc[744, 'score'] = 1.0

locais_votacao_geoloc.loc[765, 'end_resultado'] = "R. Darci Mano, 97 - Vila Odete, São Paulo - SP, 08440-400"
locais_votacao_geoloc.loc[765, 'lat'] = -23.535296
locais_votacao_geoloc.loc[765, 'lon'] = -46.410620
locais_votacao_geoloc.loc[765, 'score'] = 1.0

locais_votacao_geoloc.loc[775, 'end_resultado'] = "Av. João Paulo da Silva, 259 - Vila da Paz, São Paulo - SP, 04777-020"
locais_votacao_geoloc.loc[775, 'lat'] = -23.693790
locais_votacao_geoloc.loc[775, 'lon'] = -46.696109
locais_votacao_geoloc.loc[775, 'score'] = 1.0

locais_votacao_geoloc.loc[839, 'end_resultado'] = "Cidade Tiradentes, São Paulo - SP"
locais_votacao_geoloc.loc[839, 'lat'] = -23.570805
locais_votacao_geoloc.loc[839, 'lon'] = -46.397790
locais_votacao_geoloc.loc[839, 'score'] = 1.0

locais_votacao_geoloc.loc[863, 'end_resultado'] = "R. Pinheiro de Faria, 40 - Jardim Maristela, São Paulo - SP, 02806-040"
locais_votacao_geoloc.loc[863, 'lat'] = -23.474645
locais_votacao_geoloc.loc[863, 'lon'] = -46.700363
locais_votacao_geoloc.loc[863, 'score'] = 1.0

locais_votacao_geoloc.loc[873, 'end_resultado'] = "R. Casimiro Recuero, 66 - Jardim Maggi, São Paulo - SP, 02982-160"
locais_votacao_geoloc.loc[873, 'lat'] = -23.456670
locais_votacao_geoloc.loc[873, 'lon'] = -46.717212
locais_votacao_geoloc.loc[873, 'score'] = 1.0

locais_votacao_geoloc.loc[930, 'end_resultado'] = "R. Jívaros, 72 - Parque Bologne, São Paulo - SP, 04941-110"
locais_votacao_geoloc.loc[930, 'lat'] = -23.700670
locais_votacao_geoloc.loc[930, 'lon'] = -46.775512
locais_votacao_geoloc.loc[930, 'score'] = 1.0

locais_votacao_geoloc.loc[957, 'end_resultado'] = "Rua Manoel de Sousa Azevedo, 364 - Freguesia do Ó, São Paulo - SP, 02809-040"
locais_votacao_geoloc.loc[957, 'lat'] = -23.471429
locais_votacao_geoloc.loc[957, 'lon'] = -46.703268
locais_votacao_geoloc.loc[957, 'score'] = 1.0

locais_votacao_geoloc.loc[968, 'end_resultado'] = "Av. Maria Santana, 230 - Vila Jacuí, São Paulo - SP, 08050-130"
locais_votacao_geoloc.loc[968, 'lat'] = -23.510970
locais_votacao_geoloc.loc[968, 'lon'] = -46.454806
locais_votacao_geoloc.loc[968, 'score'] = 1.0

locais_votacao_geoloc.loc[1067, 'end_resultado'] = "Av. da Liberdade, 654 - Liberdade, São Paulo - SP, 01502-001"
locais_votacao_geoloc.loc[1067, 'lat'] = -23.558127
locais_votacao_geoloc.loc[1067, 'lon'] = -46.637569
locais_votacao_geoloc.loc[1067, 'score'] = 1.0

locais_votacao_geoloc.loc[1216, 'end_resultado'] = "R. Belo Jardim, 674 - Jardim Mutinga, São Paulo - SP, 05159-200"
locais_votacao_geoloc.loc[1216, 'lat'] = -23.485612
locais_votacao_geoloc.loc[1216, 'lon'] = -46.751285
locais_votacao_geoloc.loc[1216, 'score'] = 1.0

locais_votacao_geoloc.loc[1266, 'end_resultado'] = "R. Manuel da Nóbrega, 307 - Paraíso, São Paulo - SP, 04001-081"
locais_votacao_geoloc.loc[1266, 'lat'] = -23.570171
locais_votacao_geoloc.loc[1266, 'lon'] = -46.650096
locais_votacao_geoloc.loc[1266, 'score'] = 1.0

locais_votacao_geoloc.loc[1305, 'end_resultado'] = "R. Pedro Antônio Conceição, 255 - Vila Itaberaba, São Paulo - SP, 02837-175"
locais_votacao_geoloc.loc[1305, 'lat'] = -23.460360
locais_votacao_geoloc.loc[1305, 'lon'] = -46.700055
locais_votacao_geoloc.loc[1305, 'score'] = 1.0

locais_votacao_geoloc.loc[1390, 'end_resultado'] = "R. São Luíz Gonzaga, 62 - Vila Nelson, São Paulo - SP, 02274-150"
locais_votacao_geoloc.loc[1390, 'lat'] = -23.464500
locais_votacao_geoloc.loc[1390, 'lon'] = -46.583989
locais_votacao_geoloc.loc[1390, 'score'] = 1.0

locais_votacao_geoloc.loc[1550, 'end_resultado'] = "R. Conceição do Norte, 906 - Vila Zat, São Paulo - SP, 02976-200"
locais_votacao_geoloc.loc[1550, 'lat'] = -23.473093
locais_votacao_geoloc.loc[1550, 'lon'] = -46.715016
locais_votacao_geoloc.loc[1550, 'score'] = 1.0

locais_votacao_geoloc.loc[1558, 'end_resultado'] = "Av. das Nações Unidas, 1233 - Várzea de Baixo, São Paulo - SP, 04730-090"
locais_votacao_geoloc.loc[1558, 'lat'] = -23.629260
locais_votacao_geoloc.loc[1558, 'lon'] = -46.712945
locais_votacao_geoloc.loc[1558, 'score'] = 1.0

locais_votacao_geoloc.loc[1589, 'end_resultado'] = "R. Itapira, 183 - Mooca, São Paulo - SP, 03102-060"
locais_votacao_geoloc.loc[1589, 'lat'] = -23.553257
locais_votacao_geoloc.loc[1589, 'lon'] = -46.621519
locais_votacao_geoloc.loc[1589, 'score'] = 1.0

locais_votacao_geoloc.loc[1670, 'end_resultado'] = "Av. da Liberdade, 532 - Liberdade, São Paulo - SP, 01502-001"
locais_votacao_geoloc.loc[1670, 'lat'] = -23.557090
locais_votacao_geoloc.loc[1670, 'lon'] = -46.636891
locais_votacao_geoloc.loc[1670, 'score'] = 1.0

locais_votacao_geoloc.loc[1698, 'end_resultado'] = "Av. Ramalho Ortigão, 235 - Vila Gumercindo, São Paulo - SP, 04130-010"
locais_votacao_geoloc.loc[1698, 'lat'] = -23.605464
locais_votacao_geoloc.loc[1698, 'lon'] = -46.621050
locais_votacao_geoloc.loc[1698, 'score'] = 1.0

locais_votacao_geoloc.loc[1700, 'end_resultado'] = "R. 21 de Abril, 970 - Brás, São Paulo - SP, 03047-000"
locais_votacao_geoloc.loc[1700, 'lat'] = -23.542051
locais_votacao_geoloc.loc[1700, 'lon'] = -46.605830
locais_votacao_geoloc.loc[1700, 'score'] = 1.0

locais_votacao_geoloc.loc[1720, 'end_resultado'] = "R. Imac. Conceição, 71 - Vila Buarque, São Paulo - SP, 01226-020"
locais_votacao_geoloc.loc[1720, 'lat'] = -23.538856
locais_votacao_geoloc.loc[1720, 'lon'] = -46.653189
locais_votacao_geoloc.loc[1720, 'score'] = 1.0

locais_votacao_geoloc.loc[1796, 'end_resultado'] = "Rua Luiz Viana, 110 - Jordanópolis, São Paulo - SP, 04830-370"
locais_votacao_geoloc.loc[1796, 'lat'] = -23.733373
locais_votacao_geoloc.loc[1796, 'lon'] = -46.700279
locais_votacao_geoloc.loc[1796, 'score'] = 1.0

locais_votacao_geoloc.loc[1801, 'end_resultado'] = "R. Manoel de Matos, 75 - Santana, São Paulo - SP, 02405-050"
locais_votacao_geoloc.loc[1801, 'lat'] = -23.491196
locais_votacao_geoloc.loc[1801, 'lon'] = -46.632735
locais_votacao_geoloc.loc[1801, 'score'] = 1.0

locais_votacao_geoloc.loc[1827, 'end_resultado'] = "Av. das Nações Unidas, 1230 - Vila Leopoldina, São Paulo - SP"
locais_votacao_geoloc.loc[1827, 'lat'] = -23.532276
locais_votacao_geoloc.loc[1827, 'lon'] = -46.747116
locais_votacao_geoloc.loc[1827, 'score'] = 1.0

locais_votacao_geoloc.loc[1877, 'end_resultado'] = "Rua Professor José de Sousa, 173 - Parque Boturussu, São Paulo - SP, 03801-010"
locais_votacao_geoloc.loc[1877, 'lat'] = -23.506275
locais_votacao_geoloc.loc[1877, 'lon'] = -46.492378
locais_votacao_geoloc.loc[1877, 'score'] = 1.0

locais_votacao_geoloc.loc[2000, 'end_resultado'] = "Av. das Nações Unidas, 1405 - Várzea de Baixo, São Paulo - SP, 04730-090"
locais_votacao_geoloc.loc[2000, 'lat'] = -23.629426
locais_votacao_geoloc.loc[2000, 'lon'] = -46.713112
locais_votacao_geoloc.loc[2000, 'score'] = 1.0

locais_votacao_geoloc.loc[2032, 'end_resultado'] = "Av. das Nações Unidas, 1525 - Várzea de Baixo, São Paulo - SP, 04794-000"
locais_votacao_geoloc.loc[2032, 'lat'] = -23.629442
locais_votacao_geoloc.loc[2032, 'lon'] = -46.713165
locais_votacao_geoloc.loc[2032, 'score'] = 1.0

# %%
locais = locais_votacao_geoloc.copy()
locais['geometry'] = locais.apply(lambda row: Point(row['lon'], row['lat']), axis=1)
locais_gdf = gpd.GeoDataFrame(locais, geometry='geometry', crs="EPSG:4326")

distritos_gdf = distritos.to_crs("EPSG:4326")

joined = gpd.sjoin(locais_gdf, distritos_gdf[['nm_distrit', 'geometry']], 
                   how='left', 
                   predicate='within')

locais_votacao_geoloc['distrito'] = joined['nm_distrit']

# %%
pd.set_option('display.max_colwidth', None)

locais_votacao_geoloc[['DS_LOCAL_VOTACAO_ENDERECO', 'query', 'end_resultado', 'score', 'lat', 'lon', 'distrito']].sample(5)
# Out:
#            DS_LOCAL_VOTACAO_ENDERECO  \
# 1605                 RUA ACURUÁ, 241
# 1125  RUA NOSSA SENHORA DA LAPA, 615
# 1962         RUA FALCHI GIANINI, 842
# 82      RUA CANCIONEIRO POPULAR, 210
# 1200      R. NOEL JOSÉ DA SILVA, 468
#
#                                                   query  \
# 1605                 rua acuruá 241 sao paulo sao paulo
# 1125  rua nossa senhora da lapa 615 sao paulo sao paulo
# 1962         rua falchi gianini 842 sao paulo sao paulo
# 82      rua cancioneiro popular 210 sao paulo sao paulo
# 1200       r noel josé da silva 468 sao paulo sao paulo
#
#                                              end_resultado  score        lat  \
# 1605                 Rua Açuruá, 241, 05053-000, São Paulo    1.0 -23.538059
# 1125  Rua Nossa Senhora da Lapa, 615, 05072-000, São Paulo    1.0 -23.524717
# 1962         Rua Falchi Gianini, 842, 03136-040, São Paulo    1.0 -23.581519
# 82      Rua Cancioneiro Popular, 210, 04710-000, São Paulo    1.0 -23.630571
# ...

# %%
locais_votacao_geoloc.shape
# Out:
# (2033, 43)

# %%
locais_votacao_geoloc['distrito'].isna().sum()
# Out:
# np.int64(1)

# %%
save_csv(locais_votacao_geoloc, 'locais_votacao_geoloc_distritos.csv')
# Out:
# Base salva em data\locais_votacao_geoloc_distritos.csv
